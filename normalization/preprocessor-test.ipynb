# %% [markdown]
# # Zebrafish pigmentation

# %% [markdown]
# This tutorial uses data from [Saunders, et al (2019)](https://elifesciences.org/articles/45181). Special thanks also go to [Lauren](https://twitter.com/LSaund11) for the tutorial improvement.
#
# In this [study](https://elifesciences.org/articles/45181), the authors profiled thousands of neural crest-derived cells from trunks of post-embryonic zebrafish. These cell classes include pigment cells, multipotent pigment cell progenitors, peripheral neurons, Schwann cells, chromaffin cells and others. These cells were collected during an active period of post-embryonic development, which has many similarities to fetal and neonatal development in mammals, when many of these cell types are migrating and differentiating as the animal transitions into its adult form. This study also explores the role of thyroid hormone (TH), a common endocrine factor, on the development of these different cell types.
#
# Such developmental and other dynamical processes are especially suitable for dynamo analysis as dynamo is designed to accurately estimate direction and magnitude of expression dynamics (`RNA velocity`), predict the entire lineage trajectory of any intial cell state (`vector field`), characterize the structure (`vector field topology`) of full gene expression space, as well as fate commitment potential (`single cell potential`).

# %% [markdown]
# Import the package and silence some warning information (mostly `is_categorical_dtype` warning from anndata)

# %%
import warnings
warnings.filterwarnings('ignore')

import dynamo as dyn 
from dynamo.configuration import DKM
import numpy as np

# %% [markdown]
# this is like R's sessionInfo() which helps you to debug version related bugs if any.

# %%
dyn.get_all_dependencies_version()
# Out:
# package dynamo-release pre-commit colorcet cvxopt hdbscan loompy matplotlib  \
# version          1.0.0     2.15.0    2.0.6  1.2.7  0.8.27  3.0.6      3.4.3
#
# package networkx   numba numdifftools   numpy pandas pynndescent  \
# version    2.6.3  0.54.0       0.9.40  1.20.3  1.3.3       0.5.4
#
# package python-igraph scikit-learn  scipy seaborn setuptools statsmodels  \
# version         0.9.6       0.24.2  1.7.1  0.11.2     58.0.4      0.12.2
#
# package    tqdm  trimap umap-learn
# version  4.62.3  1.0.15      0.5.1

# %% [markdown]
# ## Load data
#
# Dynamo comes with a few builtin sample datasets so you can familiarize with dynamo before analyzing your own dataset.
# You can read your own data via `read`, `read_loom`, `read_h5ad`, `read_h5` (powered by the [anndata](https://anndata.readthedocs.io/en/latest/anndata.AnnData.html) package) or load_NASC_seq, etc. Here I just load the zebrafish sample data that comes with dynamo. This dataset has 4181 cells and 16940 genes. Its `.obs` attribute also included `condition`, `batch` information from the original study (you should also store those information to your `.obs` attribute which is essentially a Pandas Dataframe, see more at [anndata](https://anndata.readthedocs.io/en/latest/)). `Cluster`, `Cell_type`, umap coordinates that was originally analyzed with [Monocle 3](https://cole-trapnell-lab.github.io/monocle3/) are also provided.

# %%
adata = dyn.sample_data.zebrafish()
# Out:
# |-----> Downloading data to ./data/zebrafish.h5ad

# %%
def select_genes_func(adata):
    dyn.preprocessing.select_genes_by_dispersion_general(adata, recipe="seurat")
# preprocessor = dyn.preprocessing.Preprocessor(select_genes_function=select_genes_func, use_log1p=False)
# preprocessor.preprocess_adata(adata)
select_genes_func(adata)
# Out:
# |-----> filtering genes by dispersion...
# |-----> n_top_genes is None, reserve all genes and add filter gene information
729, 994.5394, 3.5588112, 144.2043, 19.88737, 0.34359366, 0.7384447, 221.45229, 80.721245, 0.058372978, 0.05191153, 162.04324, 0.025265126, 94.60219, 37.007732, 0.63812083, 887.737, 0.10059279, 2717.619, 0.11535987, 2.59076, 0.27118433, 0.07598249, 0.33632404, 0.074356884, 15.88191, 3.1288493, 0.75709057, 2.2935402, 0.11293286, 9.624363, 7.887977, 2.0380375, 0.015337327, 0.04420064, 0.6032062, 1.0782921, 32.702293, 10.505084, 2.0393467, 0.82691056, 0.057680853, 0.0016718374, 224.5708, 0.042731702, 32.214115, 1190.4736, 4.5304985, 0.014174628, 292.70892, 1.0337124, 42.009377, 448.02542, 0.084870845, 23.974842, 3.922313, 0.008082474, 15.837804, 9.048688, 25.60251, 88.49049, 0.555715, 0.85406876, 0.6052657, 0.36292982, 1.5500629, 175.42383, 8.345856, 0.24353701, 0.029652141, 0.009965221, 291.61087, 1.2243701, 0.04054981, 0.60267764, 199.81152, 0.2879418, 0.17377678, 9.1977415, 16.975222, 52.19357, 1155.0698, 0.7097127, 133.69661, 0.33067477, 0.33739027, 1.4541411, 35.672108, 0.20911701, 222.13818, 1.2928901, 3.164880 ...
# |-----> <insert> pp_gene_means to var in AnnData Object.
# |-----> <insert> gene_vars to var in AnnData Object.
# |-----> <insert> gene_highly_variable to var in AnnData Object.
# |-----> number of selected highly variable genes: 2384
# |-----> [filter genes by dispersion] in progress: 100.0000%
# |-----> [filter genes by dispersion] finished [1.6665s]

# %%
print(adata.var[DKM.VAR_USE_FOR_PCA])
print("#genes selected:", adata.var[DKM.VAR_USE_FOR_PCA].sum())
pp_gene_list = list(adata.var_names[np.where(adata.var[DKM.VAR_USE_FOR_PCA])])
print(pp_gene_list)
# Out:
# tmsb4x        False
# rpl8          False
# ppiaa         False
# rpl10a        False
# rps4x         False
#               ...
# cdc42ep1a     False
# camk1da       False
# zdhhc22       False
# zgc:153681    False
# mmp16b        False
# Name: use_for_pca, Length: 16940, dtype: bool
# #genes selected: 2384
# ['pvalb1', 'rpl31', 'gfap', 'coro1a', 'ptmab', 'tspan18b', 'zgc:162730', 'cyp4t8', 'si:dkey-183i3.5', 'dnajb11', 'elovl7a', 'mag', 'myo1cb', 'si:ch211-286c4.6', 'krtt1c19e', 'tfpia', 'si:ch211-251b21.1', 'VPS37D', 'dcn', 'col1a1a', 'col5a1', 'postnb', 'hmgb2a', 'col1a1b', 'ccdc3b', 'mxra5a', 'vwde', 'flj13639', 'mfap5', 'col1a2', 'cst14a.2', 'pvalb7', 'tshz3b', 'psph', 'cd59', 'slc31a1', 'anxa3a', 'shmt1', 'lgals2a', 'tfec', 'rpl23', 'gstp1', 'si:dkeyp-94b4.1', 'shisa4', 'krt92', 'gch2', 'qdpra', 'pon3.2', 'cyt1', 'wu:fc46h12', 'plk3', 'dync1i2a', 'dnajb6b', 'pnp5a', 'oca2', 'tyrp1a', 'si:dkey-21a6.5', 'tyrp1b', 'slc2a15b', 'aqp3a', 'zgc:110239', 'tspan36', 'pmela', 'mlpha', 'MREG', 'p4hb', 'hmgn2', 'rps13', 'marcksl1a', 'rab27b', 'sumo3b', 'si:ch211-56a11.2', 'hoxb8a', 'eya2', 'slc22a7a', 'stmn4', 'gng3', 'spegb', 'aldh1l1', 'abcf2a', 'c1qc', 'bhlhe41', 'ctsba', 'zgc:136930', 'aldocb', 'si:dkey-16p21.8', 'cd74a', 'aldob', 'zgc:153704', 'icn', 'socs3a', 'uraha', 'vamp2', 'tnnt3b', 'mtbl', 'elovl1a', 'mylpfa', 'tsc22d1', 'adka', 'pnp4a', 'spaca4l', 'id3', 'ccl25b', 'dnase1l4.1', 'ppm1ab', 'mt2', 'fcer1gl', 'D', 'crabp1a', 'si:dkey-33c12.3', 'ak1', 'pef1', 'stxbp6l', 'krt96', 'tfap2a', 'zgc:112334', 'si:dkey-5n18.1', 'CYST', 'glula', 'ctsh', 'slc16a1a', 'pola2', 'cdk15', 'f11r.1', 'ctss2.2', 'esyt1a', 'fabp7a', 'arl6ip1', 'rtn4r', 'pcdh19', 'npas4a', 'midn', 'pax2a', 'tubb5', 'aplp1', 'slc8a1b', 'ube2c', 'wsb1', 'tmsb1', 'nos1apa', 'fxyd6l', 'capgb', 'ctss2.1', 'wasb', 'arpc1b', 'fhl2a', 'anxa2a', 'CRIP2', 'tpd52l1', 'sh3kbp1', 'zgc:110699', 'alx4a', 'si:ch211-161h7.8', 'si:dkey-4e7.3', 'acp1', 'ckmb', 'slc39a1', 'mdka', 'anxa13l', 'dek', 'nkx2.2a', 'spsb1', 'mdh1aa', 'rab6bb', 'rspry1', 'mllt11', 'id2b', 'igfbp5b', 'CABZ01032488.1', 'oacyl', 'gstp2', 'csrp2', 'rab11fip1b', 'unkl', 'wfdc2', 'krt18', 'myhz1.1', 'fez1', 'tuba1b', 'ndufa4', 'hmgb1b', 'mfap2', 'sult6b1', 'rgs5b', 'pxk', 'EMB', 'mboat1', 'cd9b', 'gapdhs', 'ppp2r5a', 'krt4', 's100v2', 'si:ch211-207n23.2', 'icn2', 'si:ch211-195b11.3', 'tmem176l.4', 'thy1', 'krt1-19d', 'unga', 'hltf', 'si:dkey-183c2.4', 'LEC', 'rxraa', 'fut9a', 'SSB', 'cx27.5', 'slc3a2a', 'si:dkey-73n8.3', 'macf1a', 'agrn', 'rnps1', 'dusp2', 'basp1', 'arrdc2', 'epcam', 'rab32a', 'lin7a', 'si:dkey-193p11.2', 'ndrg4', 'nkd1', 'cd82a', 'plp1b', 'arl5c', 'rnaset2', 'mid1ip1l', 'dub', 'mpz', 'gstm.1', 'si:ch211-139a5.9', 'zgc:153426', 'cfd', 'cd99l2', 'tuba1a', 'CU984600.2', 'pycard', 'zfp36l2', 'entpd1', 'irf8', 'pcolcea', 'scinla', 'si:ch211-222l21.1', 'atp6v1ba', 'myog', 'zgc:123068', 'calm1b', 'mdkb', 'tuba8l', 'elavl4', 'adat3', 'cdh13', 'cd99', 'ascl1b', 'pim3', 'cav1', 'asip2b', 'spint2', 'dusp5', 'si:ch211-198c19.3', 'igl3v5', 'ptgdsb.2', 'hsd11b1la', 'tmem176l.2', 'slc45a2', 'galt', 'agtrap', 'plscr3b', 'lypc', 'akap12a', 'mthfd1b', 'mlip', 'nfkbiaa', 'chd6', 'bscl2l', 'zdhhc2', 'scarb1', 'rtn1b', 'prtfdc1', 'phyhd1', 'atic', 'slc25a33', 'mocs2', 'TMEM17', 'pttg1ipb', 'pdk2b', 'ngfrb', 'igsf11', 'pbxip1b', 'tmem130', 'dhrs13a.1', 'agmo', 'sepn1', 'ccdc79', 'arhgdig', 'ndrg3a', 'prdx1', 'ppp1r14ab', 'zgc:193505', 'cxcl18b', 'slc7a11', 'tmem243a', 'si:dkey-27i16.2', 'st8sia2', 'anxa1a', 'zgc:153911', 'capn2b', 'gng2', 'atf3', 'ccl27a', 'surf6', 'tagln3b', 'ada', 'si:dkey-226k3.4', 'mxd4', 'snai1a', 'foxo1a', 'syne1b', 'gstm.3', 'rhcgl1', 'lmnb1', 'cldn7a', 'nop16', 'tuba8l2', 'rbb4l', 'ywhah', 'aldh9a1a.1', 'si:ch211-39i22.1', 'plxnb1b', 'si:ch73-56d11.5', 'itm2bb', 'rdh10a', 'si:dkey-74k8.3', 'mex3b', 'bace2', 'si:dkey-251i10.2', 'gch1', 'zgc:153031', 'paics', 'col14a1a', 'tpma', 'pvalb4', 'tnni2a.2', 'mylz3', 'cenpk', 'gapdh', 'insl5a', 'arhgef1b', 'tat', 'glud1b', 'caspbl', 'arhgap35a', 'snap25a', 'clstn2', 'col18a1', 'clybl', 'clip3', 'arf4b', 'syngr3b', 'atp2b3a', 'rgs2', 'stmn2b', 'tnni2a.4', 'postna', 'fh', 'cxcl19', 'myl1', 'creb1b', 'prkacaa', 'flna', 'camsap1b', 'CABZ01084963.1', 'tsg101b', 'nme6', 'atp1a1b', 'slc1a2b', 'elovl2', 's100b', 'mlc1', 'sdprb', 'si:ch211-156j16.1', 'si:dkey-276j7. ...

# %%
import scvelo
scvelo_adata = dyn.sample_data.zebrafish()
# dyn.preprocessing.utils.convert2symbol(scvelo_adata)
print("#genes:", len(scvelo_adata.var_names))
scvelo.pp.filter_genes_dispersion(scvelo_adata, flavor="seurat", log=True)# n_top_genes=500)
print("#genes:", len(scvelo_adata.var_names))
# Out:
# |-----> Downloading data to ./data/zebrafish.h5ad
# #genes: 16940
# Extracted 1653 highly variable genes.
# #genes: 1653

# %%
scvelo_genes = scvelo_adata.var_names

# %%
intersection = set(pp_gene_list).intersection(scvelo_genes)
print("#genes intersection:", len(intersection))
intersection = set(scvelo_genes).intersection(pp_gene_list)
print("#genes intersection:", len(intersection))
# Out:
# #genes intersection: 1652
# #genes intersection: 1652

# %%
from numpy import *
from matplotlib.pyplot import *

import sys
sys.path.insert(0, 'velocitySlamSeq//slam_seq')

from dynamo_fitting import *

# %%
p0 = 100; s0 = 10; u0 = 5; alpha = 10; beta = 1; gamma = 0.5; eta = 10; gamma_p = 0.01
t = linspace(0, 10, 50)
tt = linspace(0, 10, 20)
p, s, u = sol_p(t, p0, s0, u0, alpha, beta, gamma, eta, gamma_p)
sol = sol_num(tt, p0, s0, u0, alpha, beta, gamma, eta, gamma_p)

# %%
figure(figsize=(18, 4))

subplot(131)
plot(t, u)
plot(tt, sol[:, 0], '*')
xlabel('t')
ylabel('u')

subplot(132)
plot(t, s)
plot(tt, sol[:, 1], '*')
xlabel('t')
ylabel('s')

subplot(133)
plot(t, p)
plot(tt, sol[:, 2], '*')
xlabel('t')
ylabel('p')
# Out:
# Text(0,0.5,'p')

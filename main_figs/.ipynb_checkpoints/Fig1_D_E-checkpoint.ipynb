# %%
import numpy as np
import sys
import time
import pandas as pd
import scipy.sparse
from anndata import AnnData
import scvelo as scv
scv.settings.verbosity = -1

# this is based on our previous 
sys.path.insert(0, 'velocitySlamSeq//slam_seq')

from gillespie import *
from simulation import *
from velocyto_scvelo import *

# %matplotlib inline 
import matplotlib.pyplot as plt

# use the parameters range applied in RNA-velocity paper 

p0_range = {'a': [0, 1], 'b': [0, 1], 'la': [0, 1], 'alpha_a': [10, 1000], \
            'alpha_i': [0, 10], 'sigma': [0, 1], 'beta': [0, 10], 'gamma': [0, 10]}

params = {'a': 0.1, 'b': 0.5, 'la': 0.7, 'alpha_a': 100, 'alpha_i': 1, 'sigma': 0.6, 'beta': 0.5, 'gamma': 0.1}
gene_num = 12

a = np.random.uniform(0.1, 0.8, gene_num)
b = np.random.uniform(0.1, 0.8, gene_num)
la = np.random.uniform(0.1, 0.8, gene_num)
aa = np.random.uniform(12, 800, gene_num)
ai = np.random.uniform(0.1, 9, gene_num)
si = np.random.uniform(0.1, 0.9, gene_num)
be = np.random.uniform(0.1, 9, gene_num)
ga = np.random.uniform(0.1, 9, gene_num)

# time point set to 5 - 10 
# time point set to non-steady state 

C0 = np.zeros((gene_num, 5))
t_span = [0, 50]
n_traj = 50
t_eval = np.linspace(0, 50, 50)

time0_simulate_multigene = time.time()
multi_gene_sim_res = simulate_multigene(a, b, la, aa, ai, si, be, ga, C0, t_span, n_traj, t_eval)
time1_simulate_multigene = time.time()

time0_simulate_Gillespie = time.time()
single_gene_sim_res_time, single_gene_sim_res = simulate_Gillespie(a[0], b[0], la[0], aa[0], ai[0],  
                                                                   si[0], be[0], ga[0], C0[0], t_span, n_traj, False)
time1_simulate_Gillespie = time.time()

# %%
print('Time elapse for simulate_multigene: %.2f'% (time1_simulate_multigene - time0_simulate_multigene))
print('Time elapse for simulate_Gillespie: %.2f'%(time1_simulate_Gillespie - time0_simulate_Gillespie))

# %%
# 12, 8, 5, 10: 12 genes, 8 cells, 5 species and 10 time points 
assert isinstance(multi_gene_sim_res.reshape, object)

cell_num = 50

uu, ul, su, sl = [multi_gene_sim_res[:, :, i + 1, :].reshape((gene_num, -1)) for i in range(4)]

cell_id = 11

# (12, 8, 800)

# %%
gene_id = 0
plt.subplot(221)
plt.plot(list(range(50)), uu[cell_id, :50], 'b')
plt.subplot(222)
plt.plot(list(range(cell_num)), ul[cell_id, :50], 'g')
plt.subplot(223)
plt.plot(list(range(50)), su[cell_id, :50], 'b--')
plt.subplot(224)
plt.plot(list(range(cell_num)), sl[cell_id, :50], 'g--')

# %%
time0_Simulator = time.time()
adata = Simulator(a, b, la, aa, ai, si, be, ga, C0, t_span, n_traj)
time1_Simulator = time.time()

print('Time elapse for Simulator: %.2f'% (time1_Simulator - time0_Simulator))

# %%
import numpy as np
import sys
import time
import pandas as pd
import scipy.sparse
from anndata import AnnData
import scvelo as scv
scv.settings.verbosity = -1

sys.path.insert(0, 'velocitySlamSeq//slam_seq')

from gillespie import *
from simulation import *
from velocyto_scvelo import *

# %matplotlib inline 
import matplotlib.pyplot as plt

# save all variables in the environment 
# https://stackoverflow.com/questions/2960864/how-can-i-save-all-the-variables-in-the-current-python-session

import dill                            #pip install dill --user
filename = 'moment_model_save_before_run_estimation.pkl'
# dill.dump_session(filename)

# and to load the session again:
dill.load_session(filename)
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# <ipython-input-7-74a3c987984b> in <module>
#      25
#      26 # and to load the session again:
# ---> 27 dill.load_session(filename)
#
# ~/.local/lib/python3.6/site-packages/dill/_dill.py in load_session(filename, main)
#     408         unpickler._main = main
#     409         unpickler._session = True
# --> 410         module = unpickler.load()
#     411         unpickler._session = False
#     412         main.__dict__.update(module.__dict__)
#
# EOFError: Ran out of input

# %%
# def load_modules(): 
import numpy as np
import sys
import time
import pandas as pd
import scipy.sparse
from anndata import AnnData
import scvelo as scv
scv.settings.verbosity = -1

from simulation import *

sys.path.insert(0, 'velocitySlamSeq//slam_seq')

# from gillespie import *
# from simulation import *
# from velocyto_scvelo import *

# %matplotlib inline 
# import matplotlib.pyplot as plt
# # load_modules()
# # compare with our method 

# run velocyto 
time0_run_velocyto = time.time()
vlm = run_velocyto(adata)
time1_run_velocyto = time.time()

# # run scvelo
time0_scvelo = time.time()
adata_scvelo = run_scvelo(adata)
scv.tl.recover_dynamics(adata_scvelo)
time1_scvelo = time.time()

# # run our method 
time0_adata_dynamo = time.time()
adata_dynamo = run_dynamo(adata, normalize = False, init_num = 1, sample_method = None)

time1_adata_dynamo = time.time()

# import warnings
# warnings.filterwarnings('ignore')

print('Time elapse for velocyto: %.2f'% (time1_run_velocyto - time0_run_velocyto))
print('Time elapse for scvelo: %.2f'% (time1_scvelo - time0_scvelo))
print('Time elapse for dynamo: %.2f'% (time1_adata_dynamo - time0_adata_dynamo))

# 	p0_range = {'a': [0, 1], 'b': [0, 1], 'la': [0, 1], 'alpha_a': [10, 1000], \
# 			'alpha_i': [0, 10], 'sigma': [0, 1], 'beta': [0, 10], 'gamma': [0, 10]}
# Out:
# [autoreload of scvelo.tools.dynamical_model failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/extensions/autoreload.py", line 376, in superreload
#     module = reload(module)
#   File "/usr/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/usr/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/home/xqiu/.local/lib/python3.6/site-packages/scvelo/tools/dynamical_model.py", line 4, in <module>
# ...

# %%
scv.tl.recover_dynamics(adata_scvelo, plot_results=True)

# %%
scv.pl.velocity(adata_scvelo, var_names=adata_scvelo.var_names, ncols=2)

# %%
adata_scvelo.layers['velocity']

# %%
# !pwd

# %%
# import pickle                            #pip install dill --user
# pickle.dump( favorite_color, open( "save.p", "wb" ) )
# pickle.dump(adata_scvelo, open(''))
# # # and to load the session again:
# # dill.load_session(filename)

# %%
scv.pl.velocity(adata_scvelo, var_names=adata_scvelo.var_names, ncols=2, mode = 'stochastic')

# %%
# """Color palettes in addition to matplotlib's palettes."""

# from matplotlib import cm, colors

# # Colorblindness adjusted vega_10
# # See https://github.com/theislab/scanpy/issues/387
# vega_10 = list(map(colors.to_hex, cm.tab10.colors))
# vega_10_scanpy = vega_10.copy()
# vega_10_scanpy[2] = '#279e68'  # green
# vega_10_scanpy[4] = '#aa40fc'  # purple
# vega_10_scanpy[8] = '#b5bd61'  # kakhi

# # default matplotlib 2.0 palette
# # see 'category20' on https://github.com/vega/vega/wiki/Scales#scale-range-literals
# vega_20 = list(map(colors.to_hex, cm.tab20.colors))

# # reorderd, some removed, some added
# vega_20_scanpy = [
#     *vega_20[0:14:2], *vega_20[16::2],  # dark without grey
#     *vega_20[1:15:2], *vega_20[17::2],  # light without grey
#     '#ad494a', '#8c6d31',  # manual additions
# ]
# vega_20_scanpy[2] = vega_10_scanpy[2]
# vega_20_scanpy[4] = vega_10_scanpy[4]
# vega_20_scanpy[7] = vega_10_scanpy[8]  # kakhi shifted by missing grey
# # TODO: also replace pale colors if necessary

# default_20 = vega_20_scanpy

# # https://graphicdesign.stackexchange.com/questions/3682/where-can-i-find-a-large-palette-set-of-contrasting-colors-for-coloring-many-d
# # update 1
# # orig reference http://epub.wu.ac.at/1692/1/document.pdf
# zeileis_26 = [
#     "#023fa5", "#7d87b9", "#bec1d4", "#d6bcc0", "#bb7784", "#8e063b", "#4a6fe3",
#     "#8595e1", "#b5bbe3", "#e6afb9", "#e07b91", "#d33f6a", "#11c638", "#8dd593",
#     "#c6dec7", "#ead3c6", "#f0b98d", "#ef9708", "#0fcfc0", "#9cded6", "#d5eae7",
#     "#f3e1eb", "#f6c4e1", "#f79cd4",
#     '#7f7f7f', "#c7c7c7", "#1CE6FF", "#336600"  # these last ones were added,
# ]

# default_26 = zeileis_26

# # from http://godsnotwheregodsnot.blogspot.de/2012/09/color-distribution-methodology.html
# godsnot_64 = [
#     # "#000000",  # remove the black, as often, we have black colored annotation
#     "#FFFF00", "#1CE6FF", "#FF34FF", "#FF4A46", "#008941", "#006FA6", "#A30059",
#     "#FFDBE5", "#7A4900", "#0000A6", "#63FFAC", "#B79762", "#004D43", "#8FB0FF", "#997D87",
#     "#5A0007", "#809693", "#FEFFE6", "#1B4400", "#4FC601", "#3B5DFF", "#4A3B53", "#FF2F80",
#     "#61615A", "#BA0900", "#6B7900", "#00C2A0", "#FFAA92", "#FF90C9", "#B903AA", "#D16100",
#     "#DDEFFF", "#000035", "#7B4F4B", "#A1C299", "#300018", "#0AA6D8", "#013349", "#00846F",
#     "#372101", "#FFB500", "#C2FFED", "#A079BF", "#CC0744", "#C0B9B2", "#C2FF99", "#001E09",
#     "#00489C", "#6F0062", "#0CBD66", "#EEC3FF", "#456D75", "#B77B68", "#7A87A1", "#788D66",
#     "#885578", "#FAD09F", "#FF8A9A", "#D157A0", "#BEC459", "#456648", "#0086ED", "#886F4C",
#     "#34362D", "#B4A8BD", "#00A6AA", "#452C2C", "#636375", "#A3C8C9", "#FF913F", "#938A81",
#     "#575329", "#00FECF", "#B05B6F", "#8CD0FF", "#3B9700", "#04F757", "#C8A1A1", "#1E6E00",
#     "#7900D7", "#A77500", "#6367A9", "#A05837", "#6B002C", "#772600", "#D790FF", "#9B9700",
#     "#549E79", "#FFF69F", "#201625", "#72418F", "#BC23FF", "#99ADC0", "#3A2465", "#922329",
#     "#5B4534", "#FDE8DC", "#404E55", "#0089A3", "#CB7E98", "#A4E804", "#324E72", "#6A3A4C"]

# default_64 = godsnot_64


# from typing import Mapping, Sequence


# def _plot_color_cylce(clists: Mapping[str, Sequence[str]]):
#     import numpy as np
#     import matplotlib.pyplot as plt
#     from matplotlib.colors import ListedColormap, BoundaryNorm

#     fig, axes = plt.subplots(nrows=len(clists))  # type: plt.Figure, plt.Axes
#     fig.subplots_adjust(top=.95, bottom=.01, left=.3, right=.99)
#     axes[0].set_title('Color Maps/Cycles', fontsize=14)

#     for ax, (name, clist) in zip(axes, clists.items()):
#         n = len(clist)
#         ax.imshow(
#             np.arange(n)[None, :].repeat(2, 0),
#             aspect='auto',
#             cmap=ListedColormap(clist),
#             norm=BoundaryNorm(np.arange(n+1)-.5, n),
#         )
#         pos = list(ax.get_position().bounds)
#         x_text = pos[0] - .01
#         y_text = pos[1] + pos[3] / 2.
#         fig.text(x_text, y_text, name, va='center', ha='right', fontsize=10)

#     # Turn off all ticks & spines
#     for ax in axes:
#         ax.set_axis_off()
#     fig.show()


# if __name__ == '__main__':
#     _plot_color_cylce({
#         name: colors
#         for name, colors in globals().items()
#         if isinstance(colors, list)
#     })

# %%
np.corrcoef(aa, adata_scvelo.var['fit_gamma'])[1, 0]
scvelo_coef = [np.corrcoef(aa, adata_scvelo.var['fit_alpha'])[1, 0], 
               np.corrcoef(be, adata_scvelo.var['fit_beta'])[1, 0], 
               np.corrcoef(ga, adata_scvelo.var['fit_gamma'])[1, 0], ]

adata_dynamo.uns['dynamo']["a"].values
a
adata_dynamo.uns['dynamo']["a"].values
a
np.corrcoef(a, list(adata_dynamo.uns['dynamo']["a"].values))
dynamo_coef = [np.corrcoef(a, list(adata_dynamo.uns['dynamo']["a"]))[1, 0], 
               np.corrcoef(b, list(adata_dynamo.uns['dynamo']["b"]))[1, 0], 
               np.corrcoef(la, list(adata_dynamo.uns['dynamo']["la"]))[1, 0],
               np.corrcoef(aa, list(adata_dynamo.uns['dynamo']["alpha_a"]))[1, 0],
               np.corrcoef(ai, list(adata_dynamo.uns['dynamo']["alpha_i"]))[1, 0],
               np.corrcoef(si, list(adata_dynamo.uns['dynamo']["sigma"]))[1, 0],
               np.corrcoef(be, list(adata_dynamo.uns['dynamo']["beta"]))[1, 0],
               np.corrcoef(ga, list(adata_dynamo.uns['dynamo']["gamma"]))[1, 0],

              ]

# %%
import scipy.io

# %%
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

def compare_res(adata, velocyto_res, svelo_res, dynamo_res, a_val, b_val, la_val, alpha_a_val, alpha_i_val, sigma_val, beta_val, gamma_val):
	'''
	function to compare results from velocyto and scvelo with our new method
	0. retrieve gamm or gamma with other parameters from velocyto result or scvelo
	1. plot the correlation between parameters estimated with different methods
	2. calculate the correltion between those parameters
	'''
	# self._offset, self._offset2, self._beta, self._gamma, self._r2, self._velocity_genes

	velocyto_gammas = velocyto_res.gammas
	scvelo_gammas = svelo_res.var['velocity_gamma']

	# scatter plot the true gammas with our result
	plt.subplots(figsize = (15, 5))
	plt.plot()
	plt.subplot(131)
	plt.plot(gamma_val, velocyto_gammas, 'o')
	plt.xlabel(r'True $\gamma$')
	plt.ylabel(r'$\gamma$ (velocyto)')
	plt.subplot(132)
	plt.plot(gamma_val, scvelo_gammas, 'o')
	plt.xlabel(r'True $\gamma$')
	plt.ylabel(r'$\gamma$ (scvelo)')
	plt.subplot(133)
	plt.plot(gamma_val, dynamo_res.uns['dynamo']["gamma"], 'o')
	plt.xlabel(r'True $\gamma$')
	plt.ylabel(r'$\gamma$ (dynamo)')
	plt.savefig("/home/xqiu/proj/dynamo/figures/compare_fitting_parameters1.pdf", bbox_inches='tight')

    # what if we only have a small number of parameters? 
	plt.subplots(figsize = (15, 5))
	plt.plot()
	plt.subplot(131)
	plt.plot(alpha_a_val, svelo_res.var['fit_alpha'], 'o')
	plt.xlabel(r'True alpha')
	plt.ylabel(r'$\alpha$ (scvelo)')
	plt.subplot(132)
	plt.plot(beta_val, svelo_res.var['fit_beta'], 'o')
	plt.xlabel(r'True $\beta$')
	plt.ylabel(r'$\beta$ (scvelo)')
	plt.subplot(133)
	plt.plot(gamma_val, svelo_res.var['fit_gamma'], 'o')
	plt.xlabel(r'True $\gamma$')
	plt.ylabel(r'$\gamma$ (scvelo)')
	plt.savefig("/home/xqiu/proj/dynamo/figures/compare_fitting_parameters2.pdf", bbox_inches='tight')

    #     param_out = pd.DataFrame(index=adata.var.index, columns=['a', 'b', 'la', 'alpha_a', 'alpha_i', 'sigma', 'beta', 'gamma'])
    # what if we only have a small number of parameters? 
	plt.subplots(figsize = (15, 15))
	plt.subplot(331)
	plt.plot(a_val, adata.uns['dynamo']["a"], 'o')
	plt.xlabel(r'True $a$')
	plt.ylabel(r'$a$ (dynamo)')
	plt.subplot(332)
	plt.plot(b_val, adata.uns['dynamo']["b"], 'o')
	plt.xlabel(r'True $b$')
	plt.ylabel(r'$b$ (dynamo)')
	plt.subplot(333)
	plt.plot(la_val, adata.uns['dynamo']["la"], 'o')
	plt.xlabel(r'True $l_a$')
	plt.ylabel(r'$l_a$ (dynamo)')
	plt.subplot(334)
	plt.plot(alpha_a_val, adata.uns['dynamo']["alpha_a"], 'o')
	plt.xlabel(r'True $\alpha_a$')
	plt.ylabel(r'$\alpha_a$ (dynamo)')
	plt.subplot(335)
	plt.plot(alpha_i_val, adata.uns['dynamo']["alpha_i"], 'o')
	plt.xlabel(r'True $\alpha_i$')
	plt.ylabel(r'$\alpha_i$ (dynamo)')
	plt.subplot(336)
	plt.plot(sigma_val, adata.uns['dynamo']["sigma"], 'o')
	plt.xlabel(r'True $\sigma$')
	plt.ylabel(r'$\sigma$ (dynamo)')
	plt.subplot(337)
	plt.plot(beta_val, adata.uns['dynamo']["beta"], 'o')
	plt.xlabel(r'True $\beta$')
	plt.ylabel(r'$\beta$ (dynamo)')
	plt.subplot(338)
	plt.plot(gamma_val, adata.uns['dynamo']["gamma"], 'o')
	plt.xlabel(r'True $\gamma$')
	plt.ylabel(r'$\gamma$ (dynamo)')
	plt.savefig("/home/xqiu/proj/dynamo/figures/compare_fitting_parameters3.pdf", bbox_inches='tight')
	scipy.io.savemat("/home/xqiu/proj/dynamo/data/benchmark_res.mat", {"gamma_val": gamma_val, 
                                                                       "velocyto_gammas": velocyto_gammas,
                                                                       "scvelo_alpha_a_val": svelo_res.var['fit_alpha'],
                                                                       "beta_val": beta_val,"scvelo_beta_val": svelo_res.var['fit_beta'],
                                                                       "scvelo_gamma_val": svelo_res.var['fit_gamma'],
                                                                       'a': a_val, 'dynamo_a': list(dynamo_res.uns['dynamo']["a"]), 
                                                                       'b': b_val, 'dynamo_b': list(dynamo_res.uns['dynamo']["b"]), 
                                                                       'la': la_val, 'dynamo_la': list(dynamo_res.uns['dynamo']["la"]),
                                                                       'alpha_a': alpha_a_val, 'dynamo_alpha_a': list(dynamo_res.uns['dynamo']["alpha_a"]),
                                                                       'alpha_i': alpha_i_val, 'dynamo_alpha_i': list(dynamo_res.uns['dynamo']["alpha_i"]),
                                                                       'sigma': sigma_val, 'dynamo_sigma': list(dynamo_res.uns['dynamo']["sigma"]),
                                                                       'beta': beta_val, 'dynamo_beta': list(dynamo_res.uns['dynamo']["beta"]),
                                                                       'gamma': gamma_val, 'dynamo_gamma': list(dynamo_res.uns['dynamo']["gamma"])})

	velocyto_coef = {"gamma": np.corrcoef(gamma_val, velocyto_gammas)[1, 0]}
	scvelo_coef = {"alpha": np.corrcoef(alpha_a_val, svelo_res.var['fit_alpha'])[1, 0], 
                   "beta": np.corrcoef(beta_val, svelo_res.var['fit_beta'])[1, 0], 
                   "gamma": np.corrcoef(gamma_val, svelo_res.var['fit_gamma'])[1, 0], }
    
	dynamo_coef = {'a': np.corrcoef(a_val, list(dynamo_res.uns['dynamo']["a"]))[1, 0], 
	               'b': np.corrcoef(b_val, list(dynamo_res.uns['dynamo']["b"]))[1, 0], 
	               'la': np.corrcoef(la_val, list(dynamo_res.uns['dynamo']["la"]))[1, 0],
	               'alpha_a': np.corrcoef(alpha_a_val, list(dynamo_res.uns['dynamo']["alpha_a"]))[1, 0],
	               'alpha_i': np.corrcoef(alpha_i_val, list(dynamo_res.uns['dynamo']["alpha_i"]))[1, 0],
	               'sigma': np.corrcoef(sigma_val, list(dynamo_res.uns['dynamo']["sigma"]))[1, 0],
	               'beta': np.corrcoef(beta_val, list(dynamo_res.uns['dynamo']["beta"]))[1, 0],
	               'gamma': np.corrcoef(gamma_val, list(dynamo_res.uns['dynamo']["gamma"]))[1, 0],

	              }
    
	return {'velocyto': pd.DataFrame.from_dict(velocyto_coef, orient = 'index').T, \
	'scvelo': pd.DataFrame.from_dict(scvelo_coef, orient = 'index').T, \
	'dynamo': pd.DataFrame.from_dict(dynamo_coef, orient = 'index').T}


compare_res(adata, vlm, adata_scvelo, adata_dynamo, a, b, la, aa, ai, si, be, ga)
# Out:
# {'velocyto':       gamma
#  0  0.809213, 'scvelo':       alpha      beta     gamma
#  0  0.683533  0.267767  0.357126, 'dynamo':           a         b        la   alpha_a   alpha_i     sigma      beta  \
#  0  0.235744  0.849545  0.999801  0.959555  0.524814  0.999797  0.688238
#
#        gamma
#  0  0.800384  }

# %%
from velocyto_scvelo import *
# investigate the time / accuracy dependence of our algorithm as a function of number of cells
def simulation_for_benchmark(cell_num: int, gene_num: int, max_time: int, time_points: int) -> dict: 
    a = np.random.uniform(0.1, 0.8, gene_num)
    b = np.random.uniform(0.1, 0.8, gene_num)
    la = np.random.uniform(0.1, 0.8, gene_num)
    aa = np.random.uniform(12, 800, gene_num)
    ai = np.random.uniform(0.1, 9, gene_num)
    si = np.random.uniform(0.1, 0.9, gene_num)
    be = np.random.uniform(0.1, 9, gene_num)
    ga = np.random.uniform(0.1, 9, gene_num)

    # time point set to 5 - 10 
    # time point set to non-steady state 

    C0 = np.zeros((gene_num, 5))
    t_span = [0, max_time]
    n_traj = cell_num
    t_eval = np.linspace(0, max_time, time_points)

    time0_Simulator = time.time()
    adata = Simulator(a, b, la, aa, ai, si, be, ga, C0, t_span, n_traj)
    time1_Simulator = time.time()

    print('Time elapse for Simulator: %.2f'% (time1_Simulator - time0_Simulator))

    # run velocyto 
    time0_run_velocyto = time.time()
    vlm = run_velocyto(adata)
    time1_run_velocyto = time.time()

    # # run scvelo
    import scvelo as scv
    time0_scvelo = time.time()
    adata_scvelo = run_scvelo(adata)
    scv.tl.recover_dynamics(adata_scvelo)
    time1_scvelo = time.time()

    # run our method 
    time0_adata_dynamo = time.time()
    adata_dynamo = run_dynamo(adata, normalize = False, init_num = 1) # , sample_method = None
    time1_adata_dynamo = time.time()

    velocyto_time = time1_run_velocyto - time0_run_velocyto 
    scvelo_time = time1_scvelo - time0_scvelo 
    dynamo_time = time1_adata_dynamo - time0_adata_dynamo
    
    print('Time elapse for velocyto: %.2f'% (velocyto_time))
    print('Time elapse for scvelo: %.2f'% (scvelo_time))
    print('Time elapse for dynamo: %.2f'% (dynamo_time))

    benchmark_res = compare_res(adata, vlm, adata_scvelo, adata_dynamo, a, b, la, aa, ai, si, be, ga)
    
    return {"time_lapse": {velocyto_time, scvelo_time, dynamo_time}, "benchmark_res": benchmark_res}

# %%
from velocyto_scvelo import *
    
# a = np.random.uniform(0.1, 0.8, gene_num)
# b = np.random.uniform(0.1, 0.8, gene_num)
# la = np.random.uniform(0.1, 0.8, gene_num)
# aa = np.random.uniform(12, 800, gene_num)
# ai = np.random.uniform(0.1, 9, gene_num)
# si = np.random.uniform(0.1, 0.9, gene_num)
# be = np.random.uniform(0.1, 9, gene_num)
# ga = np.random.uniform(0.1, 9, gene_num)

compare_res(adata, vlm, adata_scvelo, adata_dynamo, a, b, la, aa, ai, si, be, ga)
# import matplotlib
# fig = matplotlib.pyplot.gcf()
# fig.set_size_inches(15, 5)

# velocyto_coef = np.corrcoef(gamma_val, velocyto_gammas)[1, 0]
# scvelo_coef = [np.corrcoef(aa, adata_scvelo.var['fit_alpha'])[1, 0], 
#                np.corrcoef(be, adata_scvelo.var['fit_beta'])[1, 0], 
#                np.corrcoef(ga, adata_scvelo.var['fit_gamma'])[1, 0], ]

# dynamo_coef = [np.corrcoef(a_val, adata.uns['dynamo']["a"])[1, 0], 
#                np.corrcoef(b_val, adata.uns['dynamo']["b"])[1, 0], 
#                np.corrcoef(la_val, adata.uns['dynamo']["la"])[1, 0],
#                np.corrcoef(alpha_a_val, adata.uns['dynamo']["alpha_a"])[1, 0],
#                np.corrcoef(alpha_i_val, adata.uns['dynamo']["alpha_i"])[1, 0],
#                np.corrcoef(sigma_val, adata.uns['dynamo']["sigma"])[1, 0],
#                np.corrcoef(beta_val, adata.uns['dynamo']["beta"])[1, 0],
#                np.corrcoef(gamma_val, adata.uns['dynamo']["gamma"])[1, 0],
#               ]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-e3d39eaf70c5> in <module>
#      10 # ga = np.random.uniform(0.1, 9, gene_num)
#      11
# ---> 12 compare_res(adata, vlm, adata_scvelo, adata_dynamo, a, b, la, aa, ai, si, be, ga)
#      13 # import matplotlib
#      14 # fig = matplotlib.pyplot.gcf()
#
# NameError: name 'vlm' is not defined

# %%
adata_scvelo = run_scvelo(adata)
scv.tl.recover_dynamics(adata_scvelo)
scv.tl.DynamicsRecovery.plot_contours(adata_scvelo)
scv.tl.DynamicsRecovery.plot_derivatives(adata_scvelo)
scv.tl.DynamicsRecovery.plot_phase(adata_scvelo)
scv.tl.DynamicsRecovery.plot_regions(adata_scvelo)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-bbcc70062a21> in <module>
#       1 adata_scvelo = run_scvelo(adata)
#       2 scv.tl.recover_dynamics(adata_scvelo)
# ----> 3 scv.tl.DynamicsRecovery.plot_contours(adata_scvelo)
#       4 scv.tl.DynamicsRecovery.plot_derivatives(adata_scvelo)
#       5 scv.tl.DynamicsRecovery.plot_phase(adata_scvelo)
#
# ~/.local/lib/python3.6/site-packages/scvelo/tools/dynamical_model_utils.py in plot_contours(self, xkey, ykey, x_sight, y_sight, num, dpi, fontsize, **kwargs)
#     648     def plot_contours(self, xkey='gamma', ykey='alpha', x_sight=[-.9, .9], y_sight=[-.9, .9], num=20, dpi=None, fontsize=8, **kwargs):
#     649         from ..plotting.utils import update_axes
# --> 650         x_var = eval('self.' + xkey)
#     651         y_var = eval('self.' + ykey)
#     652
#
# ...

# %%
from velocyto_scvelo import *
time_points_res = []
for time_points in [2, 3, 4, 5, 6, 7, 8, 9, 10, 15, 20]: # 
    print('current time points number is ', time_points)
    for replicate in range(5):
        tmp = simulation_for_benchmark(cell_num = 50, gene_num = 12, max_time = 25, time_points = time_points)
        time_points_res.append(tmp)
# Out:
# current time points number is  2
# Cannot export `.obsm` and `.varm` entries to loom.The loom file will lack these fields:
# ('X_pca',)
# Time elapse for Simulator: 105.50
# /home/xqiu/.local/lib/python3.6/site-packages/scvelo/tools/dynamical_model.py:102: RuntimeWarning: divide by zero encountered in true_divide
#   tau = - 1 / beta * log((u - u_inf) / (u0 - u_inf))
# velocitySlamSeq//slam_seq/moments.py:335: RuntimeWarning: invalid value encountered in log10
#   return log10(X + 1)
# Time elapse for velocyto: 0.21
# Time elapse for scvelo: 2.03
# Time elapse for dynamo: 2.04
# Cannot export `.obsm` and `.varm` entries to loom.The loom file will lack these fields:
# ('X_pca',)
# Time elapse for Simulator: 203.14
# /home/xqiu/.local/lib/python3.6/site-packages/scvelo/tools/dynamical_model.py:102: RuntimeWarning: divide by zero encountered in true_divide
#   tau = - 1 / beta * log((u - u_inf) / (u0 - u_inf))
# Time elapse for velocyto: 0.21
# Time elapse for scvelo: 2.07
# ...

# %%
# visualize the result: 

velocyto_df = time_points_res[0]['benchmark_res']['velocyto']
scvelo_df = time_points_res[0]['benchmark_res']['scvelo']
dynamo_df = time_points_res[0]['benchmark_res']['dynamo']

for i in range(1, len(time_points_res)):
    velocyto_df = velocyto_df.append(time_points_res[i]['benchmark_res']['velocyto'], ignore_index=True)
    scvelo_df = scvelo_df.append(time_points_res[i]['benchmark_res']['scvelo'], ignore_index=True)
    dynamo_df = dynamo_df.append(time_points_res[i]['benchmark_res']['dynamo'], ignore_index=True)

time_point = np.repeat([2, 3, 4, 5, 6, 7, 8, 9, 10, 15, 20], 5)
velocyto_df.loc[:, 'time_points'] = pd.Series(time_point, index=velocyto_df.index) # velocyto_df['time_points'] = time_point
scvelo_df.loc[:, 'time_points'] = pd.Series(time_point, index=scvelo_df.index)
dynamo_df.loc[:, 'time_points'] = pd.Series(time_point, index=dynamo_df.index)

fig, ax = plt.subplots(figsize=(8,6))
bp = velocyto_df.groupby('time_points').plot(time_point, gamma, kind='box', ax=ax)

velocyto_time, scvelo_time, dynamo_time = [], [], []
for i in range(1, len(time_points_res)):
    velocyto_time.append(time_points_res[i]['time_lapse'][0])
    scvelo_time.append(time_points_res[i]['time_lapse'][1])
    dynamo_time.append(time_points_res[i]['time_lapse'][2])
    
velocyto_df.loc[:, 'running_time'] = pd.Series(velocyto_time, index=velocyto_df.index) # velocyto_df['time_points'] = time_point
scvelo_df.loc[:, 'running_time'] = pd.Series(scvelo_time, index=scvelo_df.index)
dynamo_df.loc[:, 'running_time'] = pd.Series(dynamo_time, index=dynamo_df.index)

# plt.subplots(figsize = (10, 10))
# plt.plot()
# plt.subplot(131)
# plt.plot([2, 3, 4, 5, 6, 7, 8, 9, 10, 15, 20, 30, 40, 50, 75], velocyto_df.iloc[:, 0], 'o')
# plt.subplot(131)
# plt.plot([2, 3, 4, 5, 6, 7, 8, 9, 10, 15, 20, 30, 40, 50, 75], scvelo_df.iloc[:, 0], 'o')
# plt.subplot(131)
# plt.plot([2, 3, 4, 5, 6, 7, 8, 9, 10, 15, 20, 30, 40, 50, 75], dynamo_df.iloc[:, 0], 'o')

# velocyto_df = velocyto_df.set_index(pd.Index([2, 3, 4, 5, 6, 7, 8, 9, 10, 15, 20, 30, 40, 50, 75]))
# scvelo_df = scvelo_df.set_index(pd.Index([2, 3, 4, 5, 6, 7, 8, 9, 10, 15, 20, 30, 40, 50, 75]))
# dynamo_df = dynamo_df.set_index(pd.Index([2, 3, 4, 5, 6, 7, 8, 9, 10, 15, 20, 30, 40, 50, 75]))

# velocyto_df.plot(subplots=True, figsize=(6, 6));
# scvelo_df.plot(subplots=True, figsize=(12, 6), layout = [1, 3], sharex = True);
# dynamo_df.plot(subplots=True, figsize=(12, 12), layout = [3, 3], sharex = True);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-30562f8fa788> in <module>
#      16
#      17 fig, ax = plt.subplots(figsize=(8,6))
# ---> 18 bp = velocyto_df.groupby('time_points').plot(time_point, gamma, kind='box', ax=ax)
#      19
#      20 velocyto_time, scvelo_time, dynamo_time = [], [], []
#
# NameError: name 'gamma' is not defined

# %%
plt.plot(velocyto_df['time_points'], velocyto_df['gamma'])
fig, ax = plt.subplots(figsize=(8,6))
bp = velocyto_df.plot(x = 'time_points', y = 'gamma', kind='box', ax=ax)

#data.groupby(['date','type']).count()['amount'].unstack().plot(ax=ax)

# %%
velocyto_df
# Out:
#        gamma  time_points
# 0   0.294064            2
# 1   0.903893            2
# 2   0.220162            2
# 3   0.462007            2
# 4   0.522958            2
# 5   0.510502            3
# 6   0.360809            3
# 7   0.531239            3
# 8   0.491147            3
# 9   0.671302            3
# 10  0.679452            4
# 11  0.362030            4
# 12  0.432241            4
# 13  0.777205            4
# 14  0.732832            4
# 15  0.782933            5
# 16  0.304586            5
# 17  0.439285            5
# 18 -0.159056            5
# 19  0.362669            5
# 20  0.645156            6
# 21  0.484020            6
# 22  0.575770            6
# 23  0.363928            6
# 24  0.420470            6
# 25  0.375483            7
# 26  0.725968            7
# 27  0.470678            7
# 28  0.322236            7
# 29  0.433099            7
# 30  0.511148            8
# 31  0.656099            8
# 32  0.645732            8
# 33  0.187778            8
# ...

# %%
velocyto_df

# %%
max_time_res = []

for max_time in [2, 3, 4, 5, 6, 7, 8, 9, 10, 15, 20, 30, 40, 50, 100]:
    print('current max_time is ', max_time)
    for replicate in range(5): 
        tmp = simulation_for_benchmark(cell_num = 50, gene_num = 12, max_time = max_time, time_points = 5)
        max_time_res.append(tmp)
# Out:
# current max_time is  2
# Time elapse for Simulator: 3.43
# Normalized count data: spliced, unspliced.
# computing neighbors
#     finished (0:00:04.24) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing moments based on connectivities
#     finished (0:00:00.00) --> added
#     'Ms' and 'Mu', moments of spliced/unspliced abundances (adata.layers)
# computing velocities
#     finished (0:00:00.00) --> added
#     'velocity', velocity vectors for each individual cell (adata.layers)
# computing velocity graph
#     finished (0:00:00.01) --> added
#     'velocity_graph', sparse matrix with cosine correlations (adata.uns)
# recovering dynamics
# /home/xqiu/.local/lib/python3.6/site-packages/scvelo/tools/dynamical_model.py:102: RuntimeWarning: divide by zero encountered in true_divide
#   tau = - 1 / beta * log((u - u_inf) / (u0 - u_inf))
#     finished (0:00:00.63) --> added
# ...

# %%
max_time_velocyto_df = max_time_res[0]['benchmark_res']['velocyto']
max_time_scvelo_df = max_time_res[0]['benchmark_res']['scvelo']
max_time_dynamo_df = max_time_res[0]['benchmark_res']['dynamo']

for i in range(1, len(max_time_res)):
    max_time_velocyto_df = max_time_velocyto_df.append(max_time_res[i]['benchmark_res']['velocyto'], ignore_index=True)
    max_time_scvelo_df = max_time_scvelo_df.append(max_time_res[i]['benchmark_res']['scvelo'], ignore_index=True)
    max_time_dynamo_df = max_time_dynamo_df.append(max_time_res[i]['benchmark_res']['dynamo'], ignore_index=True)

max_time_velocyto_df = max_time_velocyto_df.set_index(pd.Index([2, 3, 4, 5, 6, 7, 8, 9, 10, 15, 20, 30, 40, 50, 100]))
max_time_scvelo_df = max_time_scvelo_df.set_index(pd.Index([2, 3, 4, 5, 6, 7, 8, 9, 10, 15, 20, 30, 40, 50, 100]))
max_time_dynamo_df = max_time_dynamo_df.set_index(pd.Index([2, 3, 4, 5, 6, 7, 8, 9, 10, 15, 20, 30, 40, 50, 100]))

max_time_velocyto_df.plot(subplots=True, figsize=(6, 6));
max_time_scvelo_df.plot(subplots=True, figsize=(12, 6), layout = [1, 3], sharex = True);
max_time_dynamo_df.plot(subplots=True, figsize=(12, 12), layout = [3, 3], sharex = True);

# %%
gene_num_res = []

for gene_num in [12, 100, 500, 1000, 2000, 3000, 4000, 5000]: 
    print('current gene_num is ', gene_num)
    tmp = simulation_for_benchmark(cell_num = 5, gene_num = gene_num, max_time = 50, time_points = 5)
    gene_num_res.append(tmp)
# Out:
# current gene_num is  12
# Time elapse for Simulator: 27.52
# Normalized count data: spliced, unspliced.
# computing neighbors
#     finished (0:00:00.19) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing moments based on connectivities
#     finished (0:00:00.00) --> added
#     'Ms' and 'Mu', moments of spliced/unspliced abundances (adata.layers)
# computing velocities
#     finished (0:00:00.00) --> added
#     'velocity', velocity vectors for each individual cell (adata.layers)
# computing velocity graph
#     finished (0:00:00.05) --> added
#     'velocity_graph', sparse matrix with cosine correlations (adata.uns)
# recovering dynamics
# /home/xqiu/.local/lib/python3.6/site-packages/scvelo/tools/dynamical_model.py:102: RuntimeWarning: divide by zero encountered in true_divide
#   tau = - 1 / beta * log((u - u_inf) / (u0 - u_inf))
#     finished (0:00:00.66) --> added
# ...

# %%
gene_num_res = max_time_res[8:23]
gene_num_velocyto_df = gene_num_res[0]['benchmark_res']['velocyto']
gene_num_scvelo_df = gene_num_res[0]['benchmark_res']['scvelo']
gene_num_dynamo_df = gene_num_res[0]['benchmark_res']['dynamo']

for i in range(1, len(gene_num_res)):
    gene_num_velocyto_df = gene_num_velocyto_df.append(gene_num_res[i]['benchmark_res']['velocyto'], ignore_index=True)
    gene_num_scvelo_df = gene_num_scvelo_df.append(gene_num_res[i]['benchmark_res']['scvelo'], ignore_index=True)
    gene_num_dynamo_df = gene_num_dynamo_df.append(gene_num_res[i]['benchmark_res']['dynamo'], ignore_index=True)

gene_num_velocyto_df = gene_num_velocyto_df.set_index(pd.Index([2, 3, 4, 5, 6, 7, 8, 9, 10, 15, 20, 30, 40, 50, 75]))
gene_num_scvelo_df = gene_num_scvelo_df.set_index(pd.Index([2, 3, 4, 5, 6, 7, 8, 9, 10, 15, 20, 30, 40, 50, 75]))
gene_num_dynamo_df = gene_num_dynamo_df.set_index(pd.Index([2, 3, 4, 5, 6, 7, 8, 9, 10, 15, 20, 30, 40, 50, 75]))

gene_num_velocyto_df.plot(subplots=True, figsize=(6, 6));
gene_num_scvelo_df.plot(subplots=True, figsize=(12, 6), layout = [1, 3], sharex = True);
gene_num_dynamo_df.plot(subplots=True, figsize=(12, 12), layout = [3, 3], sharex = True);

# %%
cell_num_res = []

for cell_num in [5, 10, 25, 50, 100, 200, 400, 800, 1000]:
    print('current cell_num is ', cell_num)
    tmp = simulation_for_benchmark(cell_num, gene_num = 12, max_time = 50, time_points = 5)
    cell_num_res.append(tmp)
# Out:
# current cell_num is  5
# Time elapse for Simulator: 35.95
# Normalized count data: spliced, unspliced.
# computing neighbors
#     finished (0:00:00.20) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing moments based on connectivities
#     finished (0:00:00.00) --> added
#     'Ms' and 'Mu', moments of spliced/unspliced abundances (adata.layers)
# computing velocities
#     finished (0:00:00.00) --> added
#     'velocity', velocity vectors for each individual cell (adata.layers)
# computing velocity graph
#     finished (0:00:00.05) --> added
#     'velocity_graph', sparse matrix with cosine correlations (adata.uns)
# recovering dynamics
# /home/xqiu/.local/lib/python3.6/site-packages/scvelo/tools/dynamical_model.py:102: RuntimeWarning: divide by zero encountered in true_divide
#   tau = - 1 / beta * log((u - u_inf) / (u0 - u_inf))
#     finished (0:00:00.68) --> added
# ...

# %%
cell_num_velocyto_df = cell_num_res[0]['benchmark_res']['velocyto']
cell_num_scvelo_df = cell_num_res[0]['benchmark_res']['scvelo']
cell_num_dynamo_df = cell_num_res[0]['benchmark_res']['dynamo']

for i in range(1, len(cell_num_res)):
    cell_num_velocyto_df = cell_num_velocyto_df.append(cell_num_res[i]['benchmark_res']['velocyto'], ignore_index=True)
    cell_num_scvelo_df = cell_num_scvelo_df.append(cell_num_res[i]['benchmark_res']['scvelo'], ignore_index=True)
    cell_num_dynamo_df = cell_num_dynamo_df.append(cell_num_res[i]['benchmark_res']['dynamo'], ignore_index=True)

cell_num_velocyto_df = cell_num_velocyto_df.set_index(pd.Index([2, 3, 4, 5, 6, 7, 8, 9, 10, 15, 20, 30, 40, 50, 75]))
cell_num_scvelo_df = cell_num_scvelo_df.set_index(pd.Index([2, 3, 4, 5, 6, 7, 8, 9, 10, 15, 20, 30, 40, 50, 75]))
cell_num_dynamo_df = cell_num_dynamo_df.set_index(pd.Index([2, 3, 4, 5, 6, 7, 8, 9, 10, 15, 20, 30, 40, 50, 75]))

cell_num_velocyto_df.plot(subplots=True, figsize=(6, 6));
cell_num_scvelo_df.plot(subplots=True, figsize=(12, 6), layout = [1, 3], sharex = True);
cell_num_dynamo_df.plot(subplots=True, figsize=(12, 12), layout = [3, 3], sharex = True);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-d5bfffc94c2d> in <module>
#       8     cell_num_dynamo_df = cell_num_dynamo_df.append(cell_num_res[i]['benchmark_res']['dynamo'], ignore_index=True)
#       9
# ---> 10 cell_num_velocyto_df = cell_num_velocyto_df.set_index(pd.Index([2, 3, 4, 5, 6, 7, 8, 9, 10, 15, 20, 30, 40, 50, 75]))
#      11 cell_num_scvelo_df = cell_num_scvelo_df.set_index(pd.Index([2, 3, 4, 5, 6, 7, 8, 9, 10, 15, 20, 30, 40, 50, 75]))
#      12 cell_num_dynamo_df = cell_num_dynamo_df.set_index(pd.Index([2, 3, 4, 5, 6, 7, 8, 9, 10, 15, 20, 30, 40, 50, 75]))
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    3926         index._cleanup()
#    3927
# -> 3928         frame.index = index
#    3929
#    3930         if not inplace:
#
# ...

# %%
# adata_scvelo = scv.tl.recover_dynamics(adata_scvelo, copy=True)
# plot_phase, plot_regions, plot_derivatives, plot_contours

scv.tl.DynamicsRecovery.plot_derivatives(adata_scvelo)

# %%
scv.tl.DynamicsRecovery.plot_regions(adata_scvelo)

# %%
scv.tl.DynamicsRecovery.plot_derivatives(adata_scvelo)

# %%
scv.tl.DynamicsRecovery.plot_contours(adata_scvelo)

# %%
plt.subplots(figsize = (30, 10))
plt.subplot(231)
plt.plot(aa, adata_scvelo.var['fit_alpha'], 'o')
plt.xlabel('True alpha_a')
plt.ylabel('alpha_a (scvelo)')
plt.subplot(232)
plt.plot(be, adata_scvelo.var['fit_beta'], 'o')
plt.xlabel('True beta')
plt.ylabel('beta (scvelo)')
plt.subplot(233)
plt.plot(ga, adata_scvelo.var['fit_gamma'], 'o')
plt.xlabel('True gamma')
plt.ylabel('gamma (scvelo)')

plt.subplot(234)
plt.plot(aa, adata_dynamo.uns['our_method_params']["alpha_a"], 'o')
plt.xlabel('True alpha_a')
plt.ylabel('alpha_a (dynamo)')
plt.subplot(235)
plt.plot(be, adata_dynamo.uns['our_method_params']["beta"], 'o')
plt.xlabel('True beta')
plt.ylabel('beta (dynamo)')
plt.subplot(236)
plt.plot(ga, adata_dynamo.uns['our_method_params']["gamma"], 'o')
plt.xlabel('True gamma')
plt.ylabel('gamma (dynamo)')

# %%
import inspect
print(inspect.getsource(run_our_method))

# %%
# vlm.filter_cells(bool_array=vlm.initial_Ucell_size > np.percentile(vlm.initial_Ucell_size, 0.5))
# vlm.set_clusters(vlm.ca["SampleID"])
# vlm.score_detection_levels(min_expr_counts=40, min_cells_express=30) # score_cv_vs_mean 
# vlm.filter_genes(by_detection_levels=True)
# vlm.score_cv_vs_mean(1000, plot=True, max_expr_avg=35)
# vlm.filter_genes(by_cv_vs_mean=True)
# vlm._normalize_S(relative_size=vlm.S.sum(0),
#              target_size=vlm.S.sum(0).mean())
# vlm._normalize_U(relative_size=vlm.U.sum(0),
#              target_size=vlm.U.sum(0).mean())
# vlm.perform_PCA()
# vlm.knn_imputation(n_pca_dims=20, k=30, balanced=True, b_sight=30, b_maxl=15, n_jobs=1)
# vlm.fit_gammas()
# # vlm.plot_phase_portraits(["Igfbpl1", "Pdgfra"])
# vlm.predict_U()
# vlm.calculate_velocity()
# vlm.calculate_shift(assumption="constant_velocity")
# vlm.extrapolate_cell_at_t(delta_t=100.)
# from sklearn.manifold import TSNE
# bh_tsne = TSNE()
# vlm.ts = bh_tsne.fit_transform(vlm.pcs[:, :25])

# vlm.estimate_transition_prob(hidim="Sx_sz", embed="ts", transform="sqrt", psc=1,
#                              n_neighbors=35, knn_random=True, sampled_fraction=0.5)
# vlm.calculate_embedding_shift(sigma_corr = 0.5, expression_scaling=True)
# vlm.calculate_grid_arrows(smooth=0.2, steps=(400, 400), n_neighbors=30)

# scv.pp.filter_and_normalize(adata, min_counts=1, min_counts_u=1, n_top_genes=1000)
# scv.pp.moments(adata, n_pcs=30, n_neighbors=15)
# scv.tl.velocity(adata)
# scv.tl.velocity_graph(adata)
# scv.pl.velocity_embedding_stream(adata, legend_loc='on data')

# %%
# a few different ways to do the comparison: 
# 1. do the analysis on the intron only data 
# 2. do the analysis on the labeled data 
# 3. do the analysis on the protein dataset? 


import sys
sys.path.insert(0, 'velocitySlamSeq//slam_seq')

from simulation import *

# %%
simulate_multigene
